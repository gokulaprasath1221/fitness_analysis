# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\Admin\Desktop\data analyst\s-37 data set\jupiter woking data set\01)fitness tracking.csv")

# %%
data.head()
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  06-10-2017        5464   200              181               5
# 1  07-10-2017        6041   100              197               8
# 2  08-10-2017          25   100                0               5
# 3  09-10-2017        5461   100              174               4
# 4  10-10-2017        6915   200              223               5
#
#    bool_of_active  weight_kg
# 0               0         66
# 1               0         66
# 2               0         66
# 3               0         66
# 4             500         66

# %%
data.shape
# Out:
# (96, 7)

# %%
plt.figure(figsize=(14,5))
sns.regplot(data=data,y=data["step_count"],x=data["bool_of_active"],label="step_count")
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.regplot(data=data,y=data["calories_burned"],x=data["mood"],label="calories burned")
#plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.regplot(data=data,y=data["hours_of_sleep"],x=data["mood"],label="calories burned")
#plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
data.describe()
# Out:
#         step_count        mood  calories_burned  hours_of_sleep  \
# count    96.000000   96.000000        96.000000        96.00000
# mean   2935.937500  211.458333        93.447917         5.21875
# std    2143.384573   84.442184        71.601951         1.51625
# min      25.000000  100.000000         0.000000         2.00000
# 25%     741.000000  100.000000        21.750000         4.00000
# 50%    2987.500000  200.000000        96.000000         5.00000
# 75%    4546.250000  300.000000       149.250000         6.00000
# max    7422.000000  300.000000       243.000000         9.00000
#
#        bool_of_active  weight_kg
# count       96.000000  96.000000
# mean       218.750000  64.281250
# std        249.341237   0.627495
# min          0.000000  64.000000
# 25%          0.000000  64.000000
# 50%          0.000000  64.000000
# 75%        500.000000  64.000000
# max        500.000000  66.000000

# %%
data.dtypes
# Out:
# date               object
# step_count          int64
# mood                int64
# calories_burned     int64
# hours_of_sleep      int64
# bool_of_active      int64
# weight_kg           int64
# dtype: object

# %%
data.isnull()
# Out:
#      date  step_count   mood  calories_burned  hours_of_sleep  bool_of_active  \
# 0   False       False  False            False           False           False
# 1   False       False  False            False           False           False
# 2   False       False  False            False           False           False
# 3   False       False  False            False           False           False
# 4   False       False  False            False           False           False
# ..    ...         ...    ...              ...             ...             ...
# 91  False       False  False            False           False           False
# 92  False       False  False            False           False           False
# 93  False       False  False            False           False           False
# 94  False       False  False            False           False           False
# 95  False       False  False            False           False           False
#
#     weight_kg
# 0       False
# ...

# %%
data.isnull().sum()
# Out:
# date               0
# step_count         0
# mood               0
# calories_burned    0
# hours_of_sleep     0
# bool_of_active     0
# weight_kg          0
# dtype: int64

# %%
data["date"]=pd.to_datetime(data.date, format="%d-%m-%Y")

# %%
corr = data.corr()

plt.figure(dpi=130)
sns.heatmap(data.corr(), annot=True, fmt= '.2f')
plt.show()

# %%
data["mood"].replace({300:"Happy",200:"Neutral",100:"Sad"},inplace=True)

# %%
data["bool_of_active"].replace({0:"Inactive",500:"Active"},inplace=True)

# %%
data["calories_burned"].sum()
# Out:
# 8971

# %%
#df3['Active_percentage']=(df3['count_x']/df3['count_y'])*100
data["weight_loss_in_grams"]=(data["calories_burned"]/data["calories_burned"].sum())*2000

# %%
data["weight_loss_in_grams"].sum()
# Out:
# 2000.0

# %%
data
# Out:
#          date  step_count     mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464  Neutral              181               5
# 1  2017-10-07        6041      Sad              197               8
# 2  2017-10-08          25      Sad                0               5
# 3  2017-10-09        5461      Sad              174               4
# 4  2017-10-10        6915  Neutral              223               5
# ..        ...         ...      ...              ...             ...
# 91 2018-01-05         133      Sad                4               2
# 92 2018-01-06         153    Happy                0               8
# 93 2018-01-07         500  Neutral                0               5
# 94 2018-01-08        2127  Neutral                0               5
# 95 2018-01-09        2203    Happy                0               5
#
#    bool_of_active  weight_kg  weight_loss_in_grams
# 0        Inactive         66             40.352246
# ...

# %%
data.dtypes
# Out:
# date                    datetime64[ns]
# step_count                       int64
# mood                            object
# calories_burned                  int64
# hours_of_sleep                   int64
# bool_of_active                  object
# weight_kg                        int64
# weight_loss_in_grams           float64
# dtype: object

# %%
plt.figure(figsize=(14,5))
sns.regplot(data=data,y=data["step_count"],x=data["calories_burned"],label="step_count")
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.regplot(data=data,y=data["step_count"],x=data["weight_loss_in_grams"],label="step_count")
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
#delete it
plt.figure(figsize=(14,5))
sns.lineplot(data=data,y=data["mood"],x=data["weight_loss_in_grams"],label="step_count")


plt.legend()
plt.show()

# %%
# %of activeness

data["bool_of_active"].value_counts(normalize=True)
# Out:
# bool_of_active
# Inactive    0.5625
# Active      0.4375
# Name: proportion, dtype: float64

# %%
pie_chart=data["bool_of_active"].value_counts(normalize=True)
plt.figure(figsize=(6,9))
labels=pie_chart.index
plt.pie(pie_chart,labels=labels,autopct="%1.1f%%")
plt.legend(pie_chart.index)
plt.show()

# %%
columns_to_drop=["date","weight_kg"]
grouped_active_inactive=data.drop(columns=columns_to_drop)

# %%
grouped_active_inactive
# Out:
#     step_count     mood  calories_burned  hours_of_sleep bool_of_active  \
# 0         5464  Neutral              181               5       Inactive
# 1         6041      Sad              197               8       Inactive
# 2           25      Sad                0               5       Inactive
# 3         5461      Sad              174               4       Inactive
# 4         6915  Neutral              223               5         Active
# ..         ...      ...              ...             ...            ...
# 91         133      Sad                4               2       Inactive
# 92         153    Happy                0               8       Inactive
# 93         500  Neutral                0               5         Active
# 94        2127  Neutral                0               5       Inactive
# 95        2203    Happy                0               5         Active
#
#     weight_loss_in_grams
# 0              40.352246
# 1              43.919296
# ...

# %%
cal_burn_vs_weight_loss_relation=grouped_active_inactive.groupby("bool_of_active")[["calories_burned","weight_loss_in_grams"]].mean()

cal_burn_vs_weight_loss_relation
# Out:
#                 calories_burned  weight_loss_in_grams
# bool_of_active
# Active               102.404762             22.830178
# Inactive              86.481481             19.280232

# %%
fig,ax=plt.subplots(figsize=(9,6))
ax.bar(cal_burn_vs_weight_loss_relation.index,cal_burn_vs_weight_loss_relation["weight_loss_in_grams"],width=0.3,color="Black")
ax1=ax.twinx()
ax1.plot(cal_burn_vs_weight_loss_relation.index,cal_burn_vs_weight_loss_relation["calories_burned"],marker="D",color="Red")

plt.show()

# %%
#grouped_step_count_data=new_data.groupby("step_count")[["calories_burned","weight_loss_in_grams"]].mean()
step_count_cal_burn_relation=grouped_active_inactive.groupby("bool_of_active")[["step_count","calories_burned"]].mean()

step_count_cal_burn_relation
# Out:
#                  step_count  calories_burned
# bool_of_active
# Active          3226.571429       102.404762
# Inactive        2709.888889        86.481481

# %%
fig,ax=plt.subplots(figsize=(9,6))
ax.bar(step_count_cal_burn_relation.index,step_count_cal_burn_relation["step_count"],width=0.3,color="Black")
ax1=ax.twinx()
ax1.plot(step_count_cal_burn_relation.index,step_count_cal_burn_relation["calories_burned"],marker="D",color="Red")

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have a DataFrame named 'data' with the given data

# Group the data by 'bool_of_active' and 'hours_of_sleep' and calculate the mean of 'calories_burned'
grouped_data = data.groupby(['bool_of_active', 'hours_of_sleep'])['calories_burned'].mean().unstack()

# Create a bar chart to visualize the mean calories burned for active and inactive individuals
ax = grouped_data.plot(kind='bar', figsize=(10, 6))
ax.set_ylabel('Mean Calories Burned')
ax.set_xlabel('Hours of Sleep')
ax.set_title('Mean Calories Burned by Active and Inactive Individuals')

# Customize the legend
plt.legend(['Inactive', 'Active'], title='Activity Status')

plt.show()

# %%
grouped_data
# Out:
# hours_of_sleep     2          3           4           5           6     7  \
# bool_of_active
# Active           NaN  53.333333  100.200000  118.611111   92.714286  72.5
# Inactive        73.0  49.000000  101.111111   86.105263  110.666667  75.5
#
# hours_of_sleep      8      9
# bool_of_active
# Active          113.2    NaN
# Inactive         62.0  154.0

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have a DataFrame named 'data' with the given data

# Group the data by 'bool_of_active' and 'hours_of_sleep' and calculate the mean of 'calories_burned'
grouped_data = data.groupby(['bool_of_active', 'hours_of_sleep'])['calories_burned'].mean().unstack()

# Get the 'Hours of Sleep' values
hours_of_sleep_values = grouped_data.index

# Transpose the DataFrame for plotting
grouped_data = grouped_data.transpose()

# Create a bar chart to visualize the mean calories burned for active and inactive individuals
ax = grouped_data.plot(kind='bar', figsize=(10, 6))
ax.set_ylabel('Mean Calories Burned')
ax.set_xlabel('Hours of Sleep')
ax.set_title('Mean Calories Burned by Active and Inactive Individuals')

# Customize the legend
plt.legend(['Inactive', 'Active'], title='Activity Status')

plt.show()

# %%
chart=data.groupby("bool_of_active")["mood"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[226], line 1
# ----> 1 chart=data.groupby("bool_of_active")["mood"]
#
# AttributeError: 'dict' object has no attribute 'groupby'

# %%
import pandas as pd

# Sample data as a dictionary
data = {
    "step_count": [5464, 6041, 25],
    "mood": ["Neutral", "Sad", "Happy"],
    "calories_burned": [181, 197, 0],
    "hours_of_sleep": [5, 8, 5],
    "bool_of_active": ["Inactive", "Inactive", "Inactive"],
    "weight_loss_in_grams": [40.352246, 43.919296, 0.000000]
}

# Convert the dictionary into a DataFrame
df = pd.DataFrame(data)

# Group by "bool_of_active" and count the occurrences of each "mood"
chart = df.groupby("bool_of_active")["mood"].value_counts()

# Display the result
print(chart)
# Out:
# bool_of_active  mood
# Inactive        Happy      1
#                 Neutral    1
#                 Sad        1
# Name: count, dtype: int64

# %%
new_data=data

# %%
columns_to_drop=["date","mood","hours_of_sleep","bool_of_active","weight_kg"]
new_data.drop(columns=columns_to_drop,inplace=True)

# %%
new_data=data.groupby(["step_count"]).sum()

# %%
new_data.dtypes
# Out:
# calories_burned           int64
# weight_loss_in_grams    float64
# dtype: object

# %%
new_data
# Out:
#             calories_burned  weight_loss_in_grams
# step_count
# 25                        0              0.000000
# 36                        1              0.222941
# 61                        1              0.222941
# 133                       4              0.891762
# 153                       0              0.000000
# ...                     ...                   ...
# 6676                    220             49.046929
# 6915                    223             49.715751
# 6930                    234             52.168097
# 7102                    227             50.607513
# 7422                    243             54.174562
#
# [94 rows x 2 columns]

# %%
plt.figure(figsize=(9,6))
label=("Active_percentage",)
plt.bar(x=df3['hours_of_sleep'],height=df3['Active_percentage'],width=0.5,color="#00FFFF")
plt.xlabel("Hours_of_sleep",fontsize=12,weight="bold")
plt.ylabel("% of Activeness",fontsize=12,weight="bold")
plt.title("Sleep vs Activeness",fontsize=16,weight="bold")
plt.legend(labels=label,loc=2)
plt.ylim(0,100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 plt.figure(figsize=(9,6))
#       2 label=("Active_percentage",)
# ----> 3 plt.bar(x=df3['hours_of_sleep'],height=df3['Active_percentage'],width=0.5,color="#00FFFF")
#       4 plt.xlabel("Hours_of_sleep",fontsize=12,weight="bold")
#       5 plt.ylabel("% of Activeness",fontsize=12,weight="bold")
#
# NameError: name 'df3' is not defined

# %%
 plt.figure(figsize = (20,6))

ax = fig.add_subplot(132)
plt.bar(x=new_data.index,height= new_data['calories_burned'],width=50)
plt.title('Day of Week vs. Step Count', fontsize=15)
plt.xlabel('Step Count', fontsize=14)
plt.ylabel('calories_burned', fontsize=14)
ax.axhline(300, color="orangered", linestyle='--')
ax.axhline(100, color="orange", linestyle='--')

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named "new_data" with a "step_count" column as the index
new_data = new_data.reset_index()  # Reset the index if "step_count" is already the index

# Extract the data from the DataFrame
calories_burned = new_data['calories_burned']
weight_loss_grams = new_data['weight_loss_in_grams']
step_count = new_data['step_count']

# Create a figure and axis
fig, ax = plt.subplots()

# Plot calories burned
ax.plot(step_count, calories_burned, label='Calories Burned')

# Plot weight loss in grams
ax.plot(step_count, weight_loss_grams, label='Weight Loss (g)')

# Plot step count
ax.plot(step_count, step_count, label='Step Count')  # Using step_count as the index

# Customize the plot
ax.set_xlabel('Step Count')
ax.set_ylabel('Values')
ax.set_title('Fitness Data')
ax.legend()  # Display legend to distinguish between lines

# Display the plot
plt.show()

# %%
new_data .loc[new_data ["step_count"] <= 1000, "step_count"] = 1
new_data .loc[(new_data ["step_count"] > 1000) & (new_data ["step_count"] <= 3000), "step_count"] = 2
new_data .loc[(new_data ["step_count"] > 3000) & (new_data ["step_count"] <= 5000), "step_count"] = 3
new_data .loc[new_data ["step_count"] > 5000, "step_count"] = 4

# %%
new_data
# Out:
#     step_count  calories_burned  weight_loss_in_grams
# 0            1                0              0.000000
# 1            1                1              0.222941
# 2            1                1              0.222941
# 3            1                4              0.891762
# 4            1                0              0.000000
# ..         ...              ...                   ...
# 89           4              220             49.046929
# 90           4              223             49.715751
# 91           4              234             52.168097
# 92           4              227             50.607513
# 93           4              243             54.174562
#
# [94 rows x 3 columns]

# %%
#df14['step_count'].replace({1: "1-1000", 2:"1001-3000", 3: "30001-5000",4:"Above5000"}, inplace=True)
new_data["step_count"].replace({1:"1-1000",2:"1001-3000",3:"3001-5000",4:"Above5000"},inplace=True)

# %%
fig,ax=plt.subplots(figsize=(9,6))
ax.bar(new_data["step_count"],new_data["calories_burned"],width=0.3,color="Black")
ax1=ax.twinx()
ax1.plot(new_data["step_count"],new_data["weight_loss_in_grams"],marker="D",color="Red")

plt.show()

# %%
grouped_step_count_data=new_data.groupby("step_count")[["calories_burned","weight_loss_in_grams"]].mean()

# %%
fig,ax=plt.subplot(figsize=(6,9))
ax.bar(new_data[""])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 fig,ax=plt.subplot(figsize=(6,9))
#       2 ax.bar(new_data[""])
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1338, in subplot(*args, **kwargs)
#    1335             break
#    1336 else:
#    1337     # we have exhausted the known Axes and none match, make a new one!
# -> 1338     ax = fig.add_subplot(*args, **kwargs)
#    1340 fig.sca(ax)
#    1342 axes_to_delete = [other for other in fig.axes
#    1343                   if other != ax and ax.bbox.fully_overlaps(other.bbox)]
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:757, in FigureBase.add_subplot(self, *args, **kwargs)
#     754         args = tuple(map(int, str(args[0])))
#     755     projection_class, pkw = self._process_projection_requirements(
#     756         *args, **kwargs)
# ...

# %%
grouped_step_count_data
# Out:
#             calories_burned  weight_loss_in_grams
# step_count
# 1-1000            12.785714              2.850455
# 1001-3000         54.300000             12.105674
# 3001-5000        133.387097             29.737398
# Above5000        226.133333             50.414298

# %%
fig,ax=plt.subplots(figsize=(9,6))
ax.bar(grouped_step_count_data.index,grouped_step_count_data["calories_burned"])


plt.show()

# %%
fig,ax=plt.subplots(figsize=(9,6))
ax.bar(grouped_step_count_data.index,grouped_step_count_data["calories_burned"],width=0.3,color="Black")
ax1=ax.twinx()
ax1.plot(grouped_step_count_data.index,grouped_step_count_data["weight_loss_in_grams"],marker="D",color="Red")

plt.show()

# %%
#command to remove columns
#for permanent changes give inplace=true
data.drop(columns = 'weight_kg')
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 3  2017-10-09        5461   100              174               4
# 4  2017-10-10        6915   200              223               5
# ..        ...         ...   ...              ...             ...
# 91 2018-01-05         133   100                4               2
# 92 2018-01-06         153   300                0               8
# 93 2018-01-07         500   200                0               5
# 94 2018-01-08        2127   200                0               5
# 95 2018-01-09        2203   300                0               5
#
#     bool_of_active
# 0                0
# 1                0
# 2                0
# 3                0
# 4              500
# ..             ...
# 91               0
# 92               0
# ...

# %%
#command to remove rows
data.drop(index=3)
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 4  2017-10-10        6915   200              223               5
# 5  2017-10-11        4545   100              149               6
# ..        ...         ...   ...              ...             ...
# 91 2018-01-05         133   100                4               2
# 92 2018-01-06         153   300                0               8
# 93 2018-01-07         500   200                0               5
# 94 2018-01-08        2127   200                0               5
# 95 2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 4              500         66
# ...

# %%
data
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 3  2017-10-09        5461   100              174               4
# 4  2017-10-10        6915   200              223               5
# ..        ...         ...   ...              ...             ...
# 91 2018-01-05         133   100                4               2
# 92 2018-01-06         153   300                0               8
# 93 2018-01-07         500   200                0               5
# 94 2018-01-08        2127   200                0               5
# 95 2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 3                0         66
# ...

# %%
data['hours_of_sleep'].nunique()
# Out:
# 8

# %%
data['hours_of_sleep'].unique()
# Out:
# array([5, 8, 4, 6, 7, 3, 2, 9], dtype=int64)

# %%
df1=data['hours_of_sleep'].value_counts()

# %%
df1
# Out:
# hours_of_sleep
# 5    37
# 6    16
# 4    14
# 8    10
# 3     9
# 7     6
# 2     3
# 9     1
# Name: count, dtype: int64

# %%
df1
# Out:
# hours_of_sleep
# 5    37
# 6    16
# 4    14
# 8    10
# 3     9
# 7     6
# 2     3
# 9     1
# Name: count, dtype: int64

# %%
#talley no missing values
data['hours_of_sleep'].sum()
# Out:
# 501

# %%
#activity 500= active
# take only active days
#count it against hours of sleep

# %%
active_vs_sleep=data[data['bool_of_active']==500]

# %%
active_vs_sleep
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 4  2017-10-10        6915   200              223               5
# 12 2017-10-18        4732   300              150               6
# 25 2017-10-31        4550   300              150               8
# 30 2017-11-05         539   300               17               5
# 36 2017-11-11        6314   300              193               6
# 37 2017-11-12         614   300               19               4
# 38 2017-11-13        3149   300              101               5
# 39 2017-11-14        4005   300              139               8
# 40 2017-11-15        4880   300              164               4
# 41 2017-11-16        4136   300              137               5
# 42 2017-11-17         705   300               22               6
# 43 2017-11-18         570   200               17               5
# 44 2017-11-19         269   300                9               6
# ...

# %%
df2=active_vs_sleep.groupby('hours_of_sleep')['bool_of_active'].value_counts()

# %%
df2
# Out:
# hours_of_sleep  bool_of_active
# 3               500                3
# 4               500                5
# 5               500               18
# 6               500                7
# 7               500                4
# 8               500                5
# Name: count, dtype: int64

# %%
#df3 = pd.merge(df1,df2,how='outer',left_on=['ID','Country','Year'],right_on=['ID',"Country","Year"])

# %%
df3=pd.merge(df2,df1,how='outer',left_on=['hours_of_sleep'],right_on=['hours_of_sleep'])

# %%
#count of hours of sleep vs count of active 
df3
# Out:
#                 count_x  count_y
# hours_of_sleep
# 3                   3.0        9
# 4                   5.0       14
# 5                  18.0       37
# 6                   7.0       16
# 7                   4.0        6
# 8                   5.0       10
# 2                   NaN        3
# 9                   NaN        1

# %%
df3.sort_values(by=['hours_of_sleep'],ascending=True,inplace=True)

# %%
df3
# Out:
#                 count_x  count_y
# hours_of_sleep
# 2                   NaN        3
# 3                   3.0        9
# 4                   5.0       14
# 5                  18.0       37
# 6                   7.0       16
# 7                   4.0        6
# 8                   5.0       10
# 9                   NaN        1

# %%
df3.isnull().sum()
# Out:
# count_x    2
# count_y    0
# dtype: int64

# %%
#df['DataFrame Column'] = df['DataFrame Column'].fillna(0)
df3['count_x']=df3['count_x'].fillna(0)

# %%
df3
# Out:
#                 count_x  count_y
# hours_of_sleep
# 2                   0.0        3
# 3                   3.0        9
# 4                   5.0       14
# 5                  18.0       37
# 6                   7.0       16
# 7                   4.0        6
# 8                   5.0       10
# 9                   0.0        1

# %%
df3.dtypes
# Out:
# count_x    float64
# count_y      int64
# dtype: object

# %%
#Apple_farm['Perc_Good'] = (Apple_farm['Good_apples'] / Apple_farm['Total_apples']) *100

df3['Active_percentage']=(df3['count_x']/df3['count_y'])*100

# %%
df3
# Out:
#                 count_x  count_y  Active_percentage
# hours_of_sleep
# 2                   0.0        3           0.000000
# 3                   3.0        9          33.333333
# 4                   5.0       14          35.714286
# 5                  18.0       37          48.648649
# 6                   7.0       16          43.750000
# 7                   4.0        6          66.666667
# 8                   5.0       10          50.000000
# 9                   0.0        1           0.000000

# %%
#elemenating 9 since it has very less values
df3.drop(index=9,inplace=True)

# %%
df3
# Out:
#                 count_x  count_y  Active_percentage
# hours_of_sleep
# 2                   0.0        3           0.000000
# 3                   3.0        9          33.333333
# 4                   5.0       14          35.714286
# 5                  18.0       37          48.648649
# 6                   7.0       16          43.750000
# 7                   4.0        6          66.666667
# 8                   5.0       10          50.000000

# %%
#inplace to be added to make it as permanent
df3.reset_index(inplace=True)

# %%
df3
# Out:
#    hours_of_sleep  count_x  count_y  Active_percentage
# 0               2      0.0        3           0.000000
# 1               3      3.0        9          33.333333
# 2               4      5.0       14          35.714286
# 3               5     18.0       37          48.648649
# 4               6      7.0       16          43.750000
# 5               7      4.0        6          66.666667
# 6               8      5.0       10          50.000000

# %%
#when sleep increases the % of activeness increases
plt.figure(figsize=(9,6))
label=("Active_percentage",)
plt.bar(x=df3['hours_of_sleep'],height=df3['Active_percentage'],width=0.5,color="#00FFFF")
plt.xlabel("Hours_of_sleep",fontsize=12,weight="bold")
plt.ylabel("% of Activeness",fontsize=12,weight="bold")
plt.title("Sleep vs Activeness",fontsize=16,weight="bold")
plt.legend(labels=label,loc=2)
plt.ylim(0,100)
plt.show()

# %%
#no2 comparision
#step_count vs calories_burned
data
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 3  2017-10-09        5461   100              174               4
# 4  2017-10-10        6915   200              223               5
# ..        ...         ...   ...              ...             ...
# 91 2018-01-05         133   100                4               2
# 92 2018-01-06         153   300                0               8
# 93 2018-01-07         500   200                0               5
# 94 2018-01-08        2127   200                0               5
# 95 2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 3                0         66
# ...

# %%
#df1 = df[['a', 'b']]
step_countvscalories_burned=data[['step_count','calories_burned']]

# %%
df4=step_countvscalories_burned

# %%
df4
# Out:
#     step_count  calories_burned
# 0         5464              181
# 1         6041              197
# 2           25                0
# 3         5461              174
# 4         6915              223
# ..         ...              ...
# 91         133                4
# 92         153                0
# 93         500                0
# 94        2127                0
# 95        2203                0
#
# [96 rows x 2 columns]

# %%
#group step_count 1-1000=1,1000-3000-2,3000-5000-3,above 5000 as 4
#df.loc[ df[“column_name”] == “some_value”, “column_name”] = “value”
#df.loc[df["gender"] == "male", "gender"] = 1
#df.loc[df['gender'] == 0, 'gender'] = gender_text[0]
#df.loc[df['gender'] == 1, 'gender'] = gender_text[1]
#df.loc[df['gender'] == 2, 'gender'] = gender_text[2]
#erroe note bracket should be behind data frame
df4.loc[df4["step_count"] <= 1000, "step_count"] = 1
df4.loc[(df4["step_count"] > 1000) & (df4["step_count"] <= 3000), "step_count"] = 2
df4.loc[(df4["step_count"] > 3000) & (df4["step_count"] <= 5000), "step_count"] = 3
df4.loc[df4["step_count"] > 5000, "step_count"] = 4
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5868\47947573.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.loc[df4["step_count"] <= 1000, "step_count"] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5868\47947573.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.loc[(df4["step_count"] > 1000) & (df4["step_count"] <= 3000), "step_count"] = 2
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5868\47947573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df4
# Out:
#     step_count  calories_burned
# 0            4              181
# 1            4              197
# 2            1                0
# 3            4              174
# 4            4              223
# ..         ...              ...
# 91           1                4
# 92           1                0
# 93           1                0
# 94           2                0
# 95           2                0
#
# [96 rows x 2 columns]

# %%
df4.isnull().sum()
# Out:
# step_count         0
# calories_burned    0
# dtype: int64

# %%
df4["step_count"].value_counts()
# Out:
# step_count
# 3    31
# 1    28
# 2    20
# 4    17
# Name: count, dtype: int64

# %%
#df.groupby('StationID').mean()
# df.groupby('StationID')['BiasTemp'].mean()
df5=df4.groupby("step_count")["calories_burned"].mean()

# %%
df5
# Out:
# step_count
# 1     12.785714
# 2     54.300000
# 3    133.387097
# 4    199.529412
# Name: calories_burned, dtype: float64

# %%
#df5 = df5.to_frame().reset_index(drop=True)
df5 = df5.to_frame()

# %%
df5.reset_index(inplace=True)

# %%
df5
# Out:
#    step_count  calories_burned
# 0           1        12.785714
# 1           2        54.300000
# 2           3       133.387097
# 3           4       199.529412

# %%
plt.figure(figsize=(9,6))
label=("calories_burned",)

plt.bar(x=df5['step_count'],height=df5['calories_burned'],width=0.5,color="orange")
plt.xlabel("step_count",fontsize=12,weight="bold")
plt.ylabel("calories burned",fontsize=12,weight="bold")
plt.title("Step_Count VS Calories_Burned",fontsize=16,weight="bold")
plt.legend(labels=label,loc=2)
plt.xticks([0,1,2,3,4])
plt.show()

# %%
df14=df5

# %%
df14['step_count'].replace({1: "1-1000", 2:"1001-3000", 3: "30001-5000",4:"Above5000"}, inplace=True)

# %%
df14
# Out:
#    step_count  calories_burned
# 0      1-1000        12.785714
# 1   1001-3000        54.300000
# 2  30001-5000       133.387097
# 3   Above5000       199.529412

# %%
plt.figure(figsize=(9,6))
label=("calories_burned",)

plt.bar(x=df5['step_count'],height=df5['calories_burned'],width=0.5,color="orange")
plt.xlabel("step_count",fontsize=12,weight="bold")
plt.ylabel("calories burned",fontsize=12,weight="bold")
plt.title("Step_Count VS Calories_Burned",fontsize=16,weight="bold")
plt.legend(labels=label,loc=2)
plt.xticks([0,1,2,3,4])
plt.show()

# %%
#to provide an insite based on day wise avg step count

# %%
data
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 3  2017-10-09        5461   100              174               4
# 4  2017-10-10        6915   200              223               5
# ..        ...         ...   ...              ...             ...
# 91 2018-01-05         133   100                4               2
# 92 2018-01-06         153   300                0               8
# 93 2018-01-07         500   200                0               5
# 94 2018-01-08        2127   200                0               5
# 95 2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 3                0         66
# ...

# %%
df6=data

# %%
df6
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 3  2017-10-09        5461   100              174               4
# 4  2017-10-10        6915   200              223               5
# ..        ...         ...   ...              ...             ...
# 91 2018-01-05         133   100                4               2
# 92 2018-01-06         153   300                0               8
# 93 2018-01-07         500   200                0               5
# 94 2018-01-08        2127   200                0               5
# 95 2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 3                0         66
# ...

# %%
df6.dtypes
# Out:
# date               datetime64[ns]
# step_count                  int64
# mood                        int64
# calories_burned             int64
# hours_of_sleep              int64
# bool_of_active              int64
# weight_kg                   int64
# dtype: object

# %%
#df6["date"] = pd.to_datetime(df6["date"], format="%d-%m-%Y")
df6["date"]=pd.to_datetime(df6.date, format="%d-%m-%Y")

# %%
df6.dtypes
# Out:
# date               datetime64[ns]
# step_count                  int64
# mood                        int64
# calories_burned             int64
# hours_of_sleep              int64
# bool_of_active              int64
# weight_kg                   int64
# dtype: object

# %%
df6["day"]=df6["date"].dt.strftime("%A")

# %%
df6
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 3  2017-10-09        5461   100              174               4
# 4  2017-10-10        6915   200              223               5
# ..        ...         ...   ...              ...             ...
# 91 2018-01-05         133   100                4               2
# 92 2018-01-06         153   300                0               8
# 93 2018-01-07         500   200                0               5
# 94 2018-01-08        2127   200                0               5
# 95 2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg       day
# 0                0         66    Friday
# 1                0         66  Saturday
# 2                0         66    Sunday
# ...

# %%
df7=df6.groupby("day")["step_count"].mean()

# %%
df7
# Out:
# day
# Friday       2220.357143
# Monday       2803.428571
# Saturday     1817.357143
# Sunday        886.142857
# Thursday     4371.384615
# Tuesday      4299.071429
# Wednesday    4357.923077
# Name: step_count, dtype: float64

# %%
#df5 = df5.to_frame().reset_index(drop=True)
df7=df7.to_frame()

# %%
df7
# Out:
#             step_count
# day
# Friday     2220.357143
# Monday     2803.428571
# Saturday   1817.357143
# Sunday      886.142857
# Thursday   4371.384615
# Tuesday    4299.071429
# Wednesday  4357.923077

# %%
df7.reset_index(inplace=True)

# %%
df7
# Out:
#          day   step_count
# 0     Friday  2220.357143
# 1     Monday  2803.428571
# 2   Saturday  1817.357143
# 3     Sunday   886.142857
# 4   Thursday  4371.384615
# 5    Tuesday  4299.071429
# 6  Wednesday  4357.923077

# %%
#step count is in mean
df8=df7

# %%
#df.reindex(['a','c','b'])
#df.reset_index(drop=True, inplace=True)
df8=df8.reindex([1,5,6,4,0,2,3])

# %%
df8
# Out:
#          day   step_count
# 1     Monday  2803.428571
# 5    Tuesday  4299.071429
# 6  Wednesday  4357.923077
# 4   Thursday  4371.384615
# 0     Friday  2220.357143
# 2   Saturday  1817.357143
# 3     Sunday   886.142857

# %%
#unexplectedly he walks more step in the middle of the week
plt.figure(figsize=(9,6))
color=["blue","orange","green","red","purple","brown","pink"]
labels=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]


plt.bar(x=df8['day'],height=df8['step_count'],color=color,width=0.5)

plt.xlabel("Days",fontsize=12,weight="bold")
plt.ylabel("Avg.Step_Count",fontsize=12,weight="bold")
plt.title("Mean Step_Walked",fontsize=16,weight="bold")

plt.xticks(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])



plt.show()

# %%
#mood vs step_count
data.head()
# Out:
#         date  step_count  mood  calories_burned  hours_of_sleep  \
# 0 2017-10-06        5464   200              181               5
# 1 2017-10-07        6041   100              197               8
# 2 2017-10-08          25   100                0               5
# 3 2017-10-09        5461   100              174               4
# 4 2017-10-10        6915   200              223               5
#
#    bool_of_active  weight_kg       day
# 0               0         66    Friday
# 1               0         66  Saturday
# 2               0         66    Sunday
# 3               0         66    Monday
# 4             500         66   Tuesday

# %%
step_countvsmood=data[['mood','step_count']]

# %%
step_countvsmood
# Out:
#     mood  step_count
# 0    200        5464
# 1    100        6041
# 2    100          25
# 3    100        5461
# 4    200        6915
# ..   ...         ...
# 91   100         133
# 92   300         153
# 93   200         500
# 94   200        2127
# 95   300        2203
#
# [96 rows x 2 columns]

# %%
#df1
df9=step_countvsmood.groupby('mood')['step_count'].value_counts()

# %%
df9
# Out:
# mood  step_count
# 100   25            1
#       36            1
#       799           1
#       3721          1
#       3519          1
#                    ..
# 300   4136          1
#       4068          1
#       4064          1
#       4033          1
#       7422          1
# Name: count, Length: 96, dtype: int64

# %%
df10=step_countvsmood.groupby('mood')['step_count'].sum()

# %%
df10
# Out:
# mood
# 100     60989
# 200     85152
# 300    135709
# Name: step_count, dtype: int64

# %%
#df.my_column.value_counts().sort_values()
df11=data.mood.value_counts().sort_values()

# %%
df11
# Out:
# mood
# 200    27
# 100    29
# 300    40
# Name: count, dtype: int64

# %%
df12=pd.merge(df11,df10,how='outer',left_on=['mood'],right_on=['mood'])

# %%
df12
# Out:
#       count  step_count
# mood
# 200      27       85152
# 100      29       60989
# 300      40      135709

# %%
df12.sort_values(by=['mood'],ascending=True,inplace=True)

# %%
df12['avg_step_count']=df12['step_count']/df12['count']

# %%
df12
# Out:
#       count  step_count  avg_step_count
# mood
# 100      29       60989     2103.068966
# 200      27       85152     3153.777778
# 300      40      135709     3392.725000

# %%
df12.reset_index(inplace=True)

# %%
df12
# Out:
#    mood  count  step_count  avg_step_count
# 0   100     29       60989     2103.068966
# 1   200     27       85152     3153.777778
# 2   300     40      135709     3392.725000

# %%
#100-sad 200-normal 300-happy

label=("step_count",)
plt.figure(figsize=(9,6))
plt.bar(x=df12['mood'],height=df12['avg_step_count'],color="red",width=20,edgecolor="none")
plt.xlabel("Mood",fontsize=12,weight="bold")
plt.ylabel("Avg_Step_Count",fontsize=12,weight="bold")
plt.title("mood vs avg_step_count",fontsize=16,weight="bold")
plt.xlim(0,350)
plt.ylim(0,5000)
plt.legend(labels=label)
plt.xticks([100,200,300])
plt.show()

# %%
df13=df12

# %%
df13
# Out:
#    mood  count  step_count  avg_step_count
# 0   100     29       60989     2103.068966
# 1   200     27       85152     3153.777778
# 2   300     40      135709     3392.725000

# %%
df13['mood'].replace({300: "Happy", 200:"Neutral", 100: "Sad"}, inplace=True)

# %%
df13
# Out:
#       mood  count  step_count  avg_step_count
# 0      Sad     29       60989     2103.068966
# 1  Neutral     27       85152     3153.777778
# 2    Happy     40      135709     3392.725000

# %%
#100-sad 200-normal 300-happy

label=("step_count",)
plt.figure(figsize=(9,6))
plt.bar(x=df12['mood'],height=df12['avg_step_count'],color="red",width=0.3,edgecolor="none")
plt.xlabel("Mood",fontsize=12,weight="bold")
plt.ylabel("Avg_Step_Count",fontsize=12,weight="bold")
plt.title("mood vs avg_step_count",fontsize=16,weight="bold")

plt.ylim(0,5000)
plt.legend(labels=label)

plt.show()
